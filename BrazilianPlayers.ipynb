# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoalAnalysis/blob/main/BrazilianPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil) (1.16.0)

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from datetime import datetime, date
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-13-db3af1e1316c>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing and displaying the last 10 players:
df = pd.ExcelFile('br-players.xlsx')
players = pd.read_excel(df, 'br-players')
players.tail(10)
# Out:
#                Name              Club Club country     Sector Position  \
# 77        Evanilson             Porto     Portugal  4. Attack  Striker
# 78    Arthur Cabral           Benfica     Portugal  4. Attack  Striker
# 79             Hulk  Atlético Mineiro       Brazil  4. Attack  Striker
# 80  Marcos Leonardo             Porto     Portugal  4. Attack  Striker
# 81             Rony         Palmeiras       Brazil  4. Attack  Striker
# 82      Richarlison         Tottenham      England  4. Attack  Striker
# 83            Pedro          Flamengo       Brazil  4. Attack  Striker
# 84  Gabriel Barbosa          Flamengo       Brazil  4. Attack  Striker
# 85          Endrick       Real Madrid        Spain  4. Attack  Striker
# 86  Tiquinho Soares          Botafogo       Brazil  4. Attack  Striker
#
#    Date of birth                                         Youth club  \
# 77    1999-10-06                                Estação, Fluminense
# 78    1998-04-25                                   Ceará, Palmeiras
# 79    1986-07-25  Serrano-PB, Campinense, Vilanovense, São Paulo...
# 80    2003-05-02                                             Santos
# 81    1995-05-11                                     Remo, Cruzeiro
# 82    1997-05-10                     Real Noroeste, América Mineiro
# 83    1997-06-20        Flamengo, Duquecaxiense, Artsul, Fluminense
# 84    1996-08-30                                             Santos
# 85    2006-06-21                                          Palmeiras
# 86    1991-01-17  Palmeiras das Rocas, Corinhians Alagoano, Amér...
#
#             City of birth State of birth Region of birth  \
# 77              Fortaleza             CE       Northeast
# 78         Campina Grande             PB       Northeast
# 79         Campina Grande             PB       Northeast
# 80             Itapetinga             BA       Northeast
# 81       Magalhães Barata             PA           North
# 82           Nova Venécia             ES       Southeast
# 83         Rio de Janeiro             RJ       Southeast
# 84  São Bernardo do Campo             SP       Southeast
# 85             Taguatinga             TO           North
# 86                  Sousa             PB       Northeast
#
#                                    Transfermarkt link Youth NT experience?
# 77  https://www.transfermarkt.co.uk/evanilson/prof...                  Yes
# 78  https://www.transfermarkt.com/arthur-cabral/pr...                  Yes
# 79  https://www.transfermarkt.com/hulk/profil/spie...                   No
# 80  https://www.transfermarkt.com/marcos-leonardo/...                  Yes
# 81  https://www.transfermarkt.com/rony/profil/spie...                   No
# 82  https://www.transfermarkt.co.uk/richarlison/pr...                  Yes
# 83  https://www.transfermarkt.co.uk/pedro/profil/s...                  Yes
# 84  https://www.transfermarkt.co.uk/gabriel-barbos...                  Yes
# 85  https://www.transfermarkt.co.uk/endrick/profil...                  Yes
# 86  https://www.transfermarkt.co.uk/tiquinho-soare...                   No

# %%
# Displaying the number of rows and columns in the dataset:
players.shape
# Out:
# (87, 12)

# %%
# Displaying the datatypes of each column:
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  87 non-null     object
#  1   Club                  87 non-null     object
#  2   Club country          87 non-null     object
#  3   Sector                87 non-null     object
#  4   Position              87 non-null     object
#  5   Date of birth         87 non-null     datetime64[ns]
#  6   Youth club            87 non-null     object
#  7   City of birth         87 non-null     object
#  8   State of birth        87 non-null     object
#  9   Region of birth       87 non-null     object
#  10  Transfermarkt link    87 non-null     object
#  11  Youth NT experience?  87 non-null     object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 8.3+ KB

# %%
# Displaying players by club:
players['Club'].value_counts().plot(kind = 'barh', color = 'yellow', figsize = (8, 12))
plt.ylabel(None)
plt.title('Players by club', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country where they play at:
players['Club country'].value_counts().plot(kind = 'barh', color = 'yellow', figsize = (8, 4))
plt.ylabel(None)
plt.title('Players by country where they play at', fontweight = 'bold')
plt.show()

# %%
# Displaying players by sector:
players['Sector'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by sector', fontweight = 'bold')
plt.show()

# %%
# Displaying players by position:
players['Position'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by position', fontweight = 'bold')
plt.show()

# %%
# Displaying players by region of birth:
players['Region of birth'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by region of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by the experience they had in the youth NT:
players['Youth NT experience?'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Youth NT experience?', fontweight = 'bold')
plt.show()

# %%
# Generating the column 'Age':
now = date.today()
players['Age'] = players.apply(lambda x: relativedelta(now, x['Date of birth']).years if x['Date of birth'] is not pd.NaT else pd.NaT, axis=1)
players.tail(50)
# Out:
#                   Name                 Club  Club country       Sector  \
# 37              Neymar             Al-Hilal  Saudi Arabia  3. Midfield
# 38      Gustavo Scarpa     Atlético Mineiro        Brazil  3. Midfield
# 39     Matheus Pereira             Cruzeiro        Brazil  3. Midfield
# 40       Lucas Paquetá             West Ham       England  3. Midfield
# 41               Cauly                Bahia        Brazil  3. Midfield
# 42           Joelinton            Newcastle       England  3. Midfield
# 43        Douglas Luiz             Juventus         Italy  3. Midfield
# 44          João Gomes        Wolverhampton       England  3. Midfield
# 45      Gabriel Menino            Palmeiras        Brazil  3. Midfield
# 46      Rodrigo Nestor            São Paulo        Brazil  3. Midfield
# 47              Gerson             Flamengo        Brazil  3. Midfield
# 48          Jean Lucas                Bahia        Brazil  3. Midfield
# 49            Casemiro    Manchester United       England  3. Midfield
# 50     Bruno Guimarães            Newcastle       England  3. Midfield
# 51              Danilo    Nottingham Forest       England  3. Midfield
# 52             Éderson             Atalanta         Italy  3. Midfield
# 53               André           Fluminense        Brazil  3. Midfield
# 54              Galeno                Porto      Portugal    4. Attack
# 55     Vinicius Junior          Real Madrid         Spain    4. Attack
# 56  Gabriel Martinelli              Arsenal       England    4. Attack
# 57                Pepê                Porto      Portugal    4. Attack
# 58            Paulinho     Atlético Mineiro        Brazil    4. Attack
# 59              Wesley        Internacional        Brazil    4. Attack
# 60                Dudu             Cruzeiro        Brazil    4. Attack
# 61      Everton Soares             Flamengo        Brazil    4. Attack
# 62      Bruno Henrique             Flamengo        Brazil    4. Attack
# 63                Tetê          Galatasaray        Turkey    4. Attack
# 64             Rodrygo          Real Madrid         Spain    4. Attack
# 65            Raphinha            Barcelona         Spain    4. Attack
# 66       Júnior Santos             Botafogo        Brazil    4. Attack
# 67         David Neres              Benfica      Portugal    4. Attack
# 42                                       Sport Recife                Aliança
# 43                                      Vasco da Gama         Rio de Janeiro
# 44                                           Flamengo         Rio de Janeiro
# 45                                 Guarani, Palmeiras              Morungaba
# 46                             Juventus-SP, São Paulo              São Paulo
# 47                                         Fluminense           Belford Roxo
# 48                  Nova Iguaçu, Bonsucesso, Flamengo         Rio de Janeiro
# 49                                          São Paulo    São José dos Campos
# 50                                   Audax Rio, Audax         Rio de Janeiro
# 51       Bahia, Jacuipense, PFC Cajazeiras, Palmeiras               Salvador
# 52       Desportivo Brasil, Shandong Luneng, Cruzeiro           Campo Grande
# 53                                         Fluminense              Ibirataia
# 54                                           Trindade         Barra do Corda
# 55                                           Flamengo            São Gonçalo
# 56                                Corinthians, Ituano              Guarulhos
# 57                    Foz do Iguaçu, Coritiba, Grêmio          Foz do Iguaçu
# 58                                      Vasco da Gama         Rio de Janeiro
# 59                                          Palmeiras               Salvador
# 60                      Atlético Goianiense, Cruzeiro                Goiânia
# 61                                  Fortaleza, Grêmio              Fortaleza
# 62                                   Inconfidência FC         Belo Horizonte
# 63                                             Grêmio               Alvorada
# 64                                             Santos                 Osasco
# 65                                               Avaí           Porto Alegre
# 66                                       Osvaldo Cruz   Conceição do Jacuípe
# 67                                          São Paulo              São Paulo
# 68                                Cruzeiro, Palmeiras                 Franca
# 69                                         Uberlândia              São Paulo
# 70                Juventus-SP, Corinthians, São Paulo              São Paulo
# 71                                   Atlético Mineiro             São Mateus
# 72                                          São Paulo            Sertãozinho
# 73                                         Fluminense             Petrópolis
# 74                                Mirassol, São Paulo           Taquaritinga
# 75                      Anápolis, Atlético Goianiense               Anápolis
# 76                              Anhanguera, Palmeiras              São Paulo
# 77                                Estação, Fluminense              Fortaleza
# 78                                   Ceará, Palmeiras         Campina Grande
# 79  Serrano-PB, Campinense, Vilanovense, São Paulo...         Campina Grande
# 80                                             Santos             Itapetinga
# 81                                     Remo, Cruzeiro       Magalhães Barata
# 82                     Real Noroeste, América Mineiro           Nova Venécia
# 83        Flamengo, Duquecaxiense, Artsul, Fluminense         Rio de Janeiro
# 84                                             Santos  São Bernardo do Campo
# 85                                          Palmeiras             Taguatinga
# 86  Palmeiras das Rocas, Corinhians Alagoano, Amér...                  Sousa
#
#    State of birth Region of birth  \
# 37             SP       Southeast
# 38             SP       Southeast
# 39             MG       Southeast
# 40             RJ       Southeast
# 41             BA       Northeast
# 42             PE       Northeast
# 43             RJ       Southeast
# 44             RJ       Southeast
# 45             SP       Southeast
# 46             SP       Southeast
# 47             RJ       Southeast
# 48             RJ       Southeast
# 49             SP       Southeast
# 50             RJ       Southeast
# 51             BA       Northeast
# 52             MS    Central-West
# 53             BA       Northeast
# 54             MA       Northeast
# 55             RJ       Southeast
# 56             SP       Southeast
# 57             PR           South
# 58             RJ       Southeast
# 59             BA       Northeast
# 60             GO    Central-West
# 61             CE       Northeast
# 62             MG       Southeast
# 63             RS           South
# 64             SP       Southeast
# 65             RS           South
# 66             BA       Northeast
# 67             SP       Southeast
# 68             SP       Southeast
# 69             SP       Southeast
# 70             SP       Southeast
# 71             ES       Southeast
# 72             SP       Southeast
# 73             RJ       Southeast
# 80  https://www.transfermarkt.com/marcos-leonardo/...                  Yes
# 81  https://www.transfermarkt.com/rony/profil/spie...                   No
# 82  https://www.transfermarkt.co.uk/richarlison/pr...                  Yes
# 83  https://www.transfermarkt.co.uk/pedro/profil/s...                  Yes
# 84  https://www.transfermarkt.co.uk/gabriel-barbos...                  Yes
# 85  https://www.transfermarkt.co.uk/endrick/profil...                  Yes
# 86  https://www.transfermarkt.co.uk/tiquinho-soare...                   No
#
#     Age
# 37   32
# 38   30
# 39   28
# 40   26
# 41   28
# 42   27
# 43   26
# 44   23
# 45   23
# 46   23
# 47   27
# 48   26
# 49   32
# 50   26
# 51   23
# 52   25
# 53   22
# 54   26
# 55   24
# 56   23
# 57   27
# 58   23
# 59   25
# 60   32
# 61   27
# 62   33
# 63   24
# 64   23
# 65   27
# 66   29
# 67   27
# 68   17
# 69   29
# 70   31
# 71   20
# 72   24
# 73   23
# 74   28
# 75   31
# 76   27
# 77   24
# 78   26
# 79   37
# 80   21
# 81   29
# 82   27
# 83   27
# 84   27
# 85   18
# 86   33

# %%
# Grouping players by their age group:
def age_groups(row):
  age = row['Age']

  if age < 20:
    return 'Under 20'
  elif age >= 20 and age < 25:
    return 'Between 20 and 24'
  elif age >= 25 and age < 30:
    return 'Between 25 and 30'
  elif age >= 30 and age <= 35:
    return 'Between 30 and 35'
  else:
    return 'Older than 35'

# Applying the function above on a column of the dataset and generating a new column as result:
players['Age group'] = players.apply(age_groups, axis=1)
players.tail()
# Out:
#                Name         Club Club country     Sector Position  \
# 82      Richarlison    Tottenham      England  4. Attack  Striker
# 83            Pedro     Flamengo       Brazil  4. Attack  Striker
# 84  Gabriel Barbosa     Flamengo       Brazil  4. Attack  Striker
# 85          Endrick  Real Madrid        Spain  4. Attack  Striker
# 86  Tiquinho Soares     Botafogo       Brazil  4. Attack  Striker
#
#    Date of birth                                         Youth club  \
# 82    1997-05-10                     Real Noroeste, América Mineiro
# 83    1997-06-20        Flamengo, Duquecaxiense, Artsul, Fluminense
# 84    1996-08-30                                             Santos
# 85    2006-06-21                                          Palmeiras
# 86    1991-01-17  Palmeiras das Rocas, Corinhians Alagoano, Amér...
#
#             City of birth State of birth Region of birth  \
# 82           Nova Venécia             ES       Southeast
# 83         Rio de Janeiro             RJ       Southeast
# 84  São Bernardo do Campo             SP       Southeast
# 85             Taguatinga             TO           North
# 86                  Sousa             PB       Northeast
#
#                                    Transfermarkt link Youth NT experience?  \
# 82  https://www.transfermarkt.co.uk/richarlison/pr...                  Yes
# 83  https://www.transfermarkt.co.uk/pedro/profil/s...                  Yes
# 84  https://www.transfermarkt.co.uk/gabriel-barbos...                  Yes
# 85  https://www.transfermarkt.co.uk/endrick/profil...                  Yes
# 86  https://www.transfermarkt.co.uk/tiquinho-soare...                   No
#
#     Age Age classification          Age group
# 82   27  Between 25 and 30  Between 25 and 30
# 83   27  Between 25 and 30  Between 25 and 30
# 84   27  Between 25 and 30  Between 25 and 30
# 85   18           Under 20           Under 20
# 86   33  Between 30 and 35  Between 30 and 35

# %%
# Displaying players by their age groups:
players['Age group'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Age groups', fontweight = 'bold')
plt.show()
