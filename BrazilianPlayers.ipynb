# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoalAnalysis/blob/main/BrazilianPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-1-88ff570e2e2d>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing and displaying the last 10 goals scored:
df = pd.ExcelFile('Non-Bayern Bundesliga Champions.xlsx')
champions = pd.read_excel(df, 'champions')
champions.tail(10)
# Out:
#      Number Position          Nation               Player              Club  \
# 151      17       GK  Czech Republic          Matěj Kovář  Bayer Leverkusen
# 152      19       MF         Nigeria         Nathan Tella  Bayer Leverkusen
# 153      36       GK         Germany          Niklas Lomb  Bayer Leverkusen
# 154      18       MF         Belgium          Noah Mbamba  Bayer Leverkusen
# 155       6       DF     Ivory Coast     Odilon Kossounou  Bayer Leverkusen
# 156      14       FW  Czech Republic        Patrik Schick  Bayer Leverkusen
# 157       3       DF         Ecuador       Piero Hincapié  Bayer Leverkusen
# 158       8       MF         Germany       Robert Andrich  Bayer Leverkusen
# 159      24       DF     Netherlands  Timothy Fosu-Mensah  Bayer Leverkusen
# 160      22       FW         Nigeria      Victor Boniface  Bayer Leverkusen
#
#      Year Leadership
# 151  2024        NaN
# 152  2024        NaN
# 153  2024        NaN
# 154  2024        NaN
# ...

# %% [markdown]
# I extracted this data from Wikipedia.

# %%
# Displaying the number of rows and columns in the dataset:
champions.shape
# Out:
# (161, 7)

# %%
# Displaying the datatypes of each column:
champions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Number      161 non-null    int64
#  1   Position    161 non-null    object
#  2   Nation      161 non-null    object
#  3   Player      161 non-null    object
#  4   Club        161 non-null    object
#  5   Year        161 non-null    int64
#  6   Leadership  9 non-null      object
# dtypes: int64(2), object(5)
# memory usage: 8.9+ KB

# %%
# Displaying champions by shirt number:
champions['Number'].value_counts().plot(kind = 'barh', color = 'red', figsize = (8, 16))
plt.ylabel(None)
plt.title('Champions by Shirt Number', fontweight = 'bold')
plt.show()

# %%
# Displaying champions by position:
champions['Position'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Champions by Position', fontweight = 'bold')
plt.show()

# %%
# Displaying champions by nation:
champions['Nation'].value_counts().plot(kind = 'barh', color = 'red', figsize = (8, 16))
plt.ylabel(None)
plt.title('Champions by Nation', fontweight = 'bold')
plt.show()

# %%
# Displaying champions by club:
champions['Club'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Champions by Club', fontweight = 'bold')
plt.show()

# %%
# Displaying champions by year:
champions['Year'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Champions by Year', fontweight = 'bold')
plt.show()

# %%
# Displaying leadership proportion (captains, vice-captains and none):
champions['Leadership'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Leadership', fontweight = 'bold')
plt.show()

# %%
# Displaying players who won Bundesliga twice by the same club:
champions_twice = champions[champions.duplicated(['Player'])]
champions_twice
# Out:
#      Number Position       Nation                Player               Club  \
# 34       21       DF  Switzerland        Ludovic Magnin          Stuttgart
# 56       25       MF      Germany     Christian Gentner          Wolfsburg
# 78       32       MF       Brazil      Antônio da Silva  Borussia Dortmund
# 107       8       MF       Brazil      Antônio da Silva  Borussia Dortmund
# 109      27       DF       Brazil        Felipe Santana  Borussia Dortmund
# 110       6       MF      Germany        Florian Kringe  Borussia Dortmund
# 113      16       MF       Poland  Jakub Błaszczykowski  Borussia Dortmund
# 114      41       GK      Germany       Johannes Focher  Borussia Dortmund
# 116      19       MF      Germany      Kevin Großkreutz  Borussia Dortmund
# 117      18       FW     Paraguay         Lucas Barrios  Borussia Dortmund
# 118      26       DF       Poland       Łukasz Piszczek  Borussia Dortmund
# ...

# %%
# Displaying players who won Bundesliga twice by the same club:
champions_twice_by_the_same_club = champions[champions.duplicated(['Player', 'Club'])]
champions_twice_by_the_same_club
# Out:
#      Number Position     Nation                Player               Club  \
# 107       8       MF     Brazil      Antônio da Silva  Borussia Dortmund
# 109      27       DF     Brazil        Felipe Santana  Borussia Dortmund
# 110       6       MF    Germany        Florian Kringe  Borussia Dortmund
# 113      16       MF     Poland  Jakub Błaszczykowski  Borussia Dortmund
# 114      41       GK    Germany       Johannes Focher  Borussia Dortmund
# 116      19       MF    Germany      Kevin Großkreutz  Borussia Dortmund
# 117      18       FW   Paraguay         Lucas Barrios  Borussia Dortmund
# 118      26       DF     Poland       Łukasz Piszczek  Borussia Dortmund
# 119      29       DF    Germany      Marcel Schmelzer  Borussia Dortmund
# 120      11       MF    Germany           Mario Götze  Borussia Dortmund
# 123      15       DF    Germany          Mats Hummels  Borussia Dortmund
# 124      20       GK  Australia     Mitchell Langerak  Borussia Dortmund
# ...
