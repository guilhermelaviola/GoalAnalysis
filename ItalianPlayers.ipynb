# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoalAnalysis/blob/main/ItalianPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil) (1.16.0)

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from datetime import datetime, date
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-2-db3af1e1316c>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing and displaying the last 10 players:
df = pd.ExcelFile('it-players.xlsx')
players = pd.read_excel(df, 'it-players')
players.tail(10)
# Out:
#                    Name       Club Club country       Sector  \
# 106      Daniel Maldini      Milan        Italy  3. Midfield
# 107   Gaetano Oristanio    Venezia        Italy  3. Midfield
# 108        Nadir Zortea   Cagliari        Italy   2. Defense
# 109       Luca D'Andrea   Sassuolo        Italy    4. Attack
# 110      Alessio Zerbin     Napoli        Italy    4. Attack
# 111       Giuseppe Caso  Frosinone        Italy    4. Attack
# 112  Samuele Mulattieri   Sassuolo        Italy    4. Attack
# 113      Andrea Petagna      Monza        Italy    4. Attack
# 114       Ciro Immobile      Lazio        Italy    4. Attack
# 115       Kelvin Yeboah      Genoa        Italy    4. Attack
#
#                   Position Date of birth        City of birth  \
# 106  7. Attacking Midfield    2001-10-11                Milan
# 107  7. Attacking Midfield    2002-09-28  Vallo della Lucania
# 108          3. Right-Back    1999-06-19               Feltre
# 109        8. Right Winger    2004-09-06               Naples
# 110         9. Left Winger    1999-03-03               Novara
# 111         9. Left Winger    1998-12-09     Torre Annunziata
# 112     11. Centre-Forward    2000-10-07            La Spezia
# 113     11. Centre-Forward    1995-06-30              Trieste
# 114     11. Centre-Forward    1990-02-20     Torre Annunziata
# 115     11. Centre-Forward    2000-05-06                Accra
#
#            Region of birth Country of birth  \
# 106               Lombardy            Italy
# 107               Campania            Italy
# 108                 Veneto            Italy
# 109               Campania            Italy
# 110               Piedmont            Italy
# 111               Campania            Italy
# 112                Liguria            Italy
# 113  Friuli-Venezia Giulia            Italy
# 114               Campania            Italy
# 115                 Abroad            Ghana
#
#                                             Youth club  \
# 106                                              Milan
# 107                                        Inter Milan
# 108       Feltreseprealpi, Südtirol, Atalanta, Venezia
# 109  Ponticelli, Mariano Keller, Scuola Calcio Azzu...
# 110         Inter Milan, Novara, Suno, Gozzano, Napoli
# 111                                         Fiorentina
# 112                                Spezia, Inter Milan
# 113                  Itala San Marco, Donatello, Milan
# 114  Torre Annunziata '88, Maria Rosa Salerno, Sale...
# 115                           West Ham United, Gozzano
#
#                                     Transfermarkt link Youth NT experience?
# 106  https://www.transfermarkt.com/daniel-maldini/p...                  Yes
# 107  https://www.transfermarkt.com/gaetano-oristani...                  Yes
# 108  https://www.transfermarkt.com/nadir-zortea/pro...                   No
# 109  https://www.transfermarkt.com/luca-dandrea/pro...                  Yes
# 110  https://www.transfermarkt.com/alessio-zerbin/p...                  Yes
# 111  https://www.transfermarkt.com/giuseppe-caso/pr...                   No
# 112  https://www.transfermarkt.com/samuele-mulattie...                  Yes
# 113  https://www.transfermarkt.com/andrea-petagna/p...                  Yes
# 114  https://www.transfermarkt.com/ciro-immobile/pr...                  Yes
# 115  https://www.transfermarkt.com/kelvin-yeboah/pr...                  Yes

# %%
# Displaying the number of rows and columns in the dataset:
players.shape
# Out:
# (116, 12)

# %%
# Displaying the datatypes of each column:
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  116 non-null    object
#  1   Club                  116 non-null    object
#  2   Club country          116 non-null    object
#  3   Sector                116 non-null    object
#  4   Position              116 non-null    object
#  5   Date of birth         116 non-null    datetime64[ns]
#  6   City of birth         116 non-null    object
#  7   Region of birth       116 non-null    object
#  8   Country of birth      116 non-null    object
#  9   Youth club            116 non-null    object
#  10  Transfermarkt link    116 non-null    object
#  11  Youth NT experience?  116 non-null    object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.0+ KB

# %%
# Displaying players by club:
players['Club'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 12))
plt.ylabel(None)
plt.title('Players by club', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country where they play at:
players['Club country'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 4))
plt.ylabel(None)
plt.title('Players by country where they play at', fontweight = 'bold')
plt.show()

# %%
# Displaying players by sector:
players['Sector'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by sector', fontweight = 'bold')
plt.show()

# %%
# Displaying players by position:
players['Position'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by position', fontweight = 'bold')
plt.show()

# %%
# Displaying players by region of birth:
players['Region of birth'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 8))
plt.ylabel(None)
plt.title('Players by region of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country of birth:
players['Country of birth'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by country of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by the experience they had in the youth NT:
players['Youth NT experience?'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Youth NT experience?', fontweight = 'bold')
plt.show()

# %%
# Generating the column 'Age':
now = date.today()
players['Age'] = players.apply(lambda x: relativedelta(now, x['Date of birth']).years if x['Date of birth'] is not pd.NaT else pd.NaT, axis=1)
players.tail(50)
# Out:
#                      Name          Club Club country       Sector  \
# 66         Nicolò Fagioli      Juventus        Italy  3. Midfield
# 67         Tommaso Pobega         Milan        Italy  3. Midfield
# 68        Giulio Maggiore   Salernitana        Italy  3. Midfield
# 69      Marco Brascianini     Frosinone        Italy  3. Midfield
# 70         Simone Pafundi      Lausanne  Switzerland  3. Midfield
# 71       Tommaso Baldanzi          Roma        Italy  3. Midfield
# 72         Andrea Colpani         Monza        Italy  3. Midfield
# 73       Cristian Volpato      Sassuolo        Italy  3. Midfield
# 74         Daniel Maldini         Milan        Italy  3. Midfield
# 75     Lorenzo Pellegrini          Roma        Italy  3. Midfield
# 76         Nicolò Zaniolo      Atalanta        Italy  3. Midfield
# 77      Giacomo Raspadori        Napoli        Italy    4. Attack
# 78       Nicolò Cambiaghi       Bologna        Italy    4. Attack
# 79    Sebastiano Esposito   Inter Milan        Italy    4. Attack
# 80       Andrea Pinamonti      Sassuolo        Italy    4. Attack
# 81          Lorenzo Lucca       Udinese        Italy    4. Attack
# 82      Francesco Camarda         Milan        Italy    4. Attack
# 83      Gianluca Scamacca      Atalanta        Italy    4. Attack
# 84          Mateo Retegui         Genoa        Italy    4. Attack
# 85             Moise Kean    Fiorentina        Italy    4. Attack
# 86        Patrick Cutrone          Como        Italy    4. Attack
# 87        Pietro Pellegri        Torino        Italy    4. Attack
# 88        Lorenzo Colombo         Milan        Italy    4. Attack
# 89       Domenico Berardi      Sassuolo        Italy    4. Attack
# 90     Matteo Cancellieri         Lazio        Italy    4. Attack
# 91        Matteo Politano        Napoli        Italy    4. Attack
# 92      Riccardo Orsolini       Bologna        Italy    4. Attack
# 93        Wilfried Gnonto  Leeds United      England    4. Attack
# 94        Mattia Zaccagni         Lazio        Italy    4. Attack
# 95          Luca Koleosho       Burnley      England    4. Attack
# 96        Federico Chiesa      Juventus        Italy    4. Attack
# 97        Riccardo Sottil    Fiorentina        Italy    4. Attack
# 98    Stephan El Shaarawy          Roma        Italy    4. Attack
# 99         Vincenzo Grifo      Freiburg      Germany    4. Attack
# 100        Giovanni Leoni     Sampdoria        Italy   2. Defense
# 101  Federico Baschirotto         Lecce        Italy   2. Defense
# 102       Tommaso Augello      Cagliari        Italy   3. Defense
# 103          Edoardo Bove          Roma        Italy  3. Midfield
# 104            Cher Ndour           PSG       France  3. Midfield
# 105      Gianluca Gaetano        Napoli        Italy  3. Midfield
# 106        Daniel Maldini         Milan        Italy  3. Midfield
# 107     Gaetano Oristanio       Venezia        Italy  3. Midfield
# 108          Nadir Zortea      Cagliari        Italy   2. Defense
# 109         Luca D'Andrea      Sassuolo        Italy    4. Attack
# 110        Alessio Zerbin        Napoli        Italy    4. Attack
# 111         Giuseppe Caso     Frosinone        Italy    4. Attack
# 112    Samuele Mulattieri      Sassuolo        Italy    4. Attack
# 113        Andrea Petagna         Monza        Italy    4. Attack
# 114         Ciro Immobile         Lazio        Italy    4. Attack
# 115         Kelvin Yeboah         Genoa        Italy    4. Attack
#
#                   Position Date of birth             City of birth  \
# 66     6. Central Midfield    2001-02-12                  Piacenza
# 67     6. Central Midfield    1999-07-15                   Trieste
# 68     6. Central Midfield    1998-03-12                     Genoa
# 69     6. Central Midfield    2000-02-20                 Calcinate
# 70   7. Attacking Midfield    2006-03-14                Monfalcone
# 71   7. Attacking Midfield    2003-03-23                Poggibonsi
# 72   7. Attacking Midfield    1999-05-11                   Brescia
# 73   7. Attacking Midfield    2003-11-15                Camperdown
# 74   7. Attacking Midfield    2001-10-11                     Milan
# 75   7. Attacking Midfield    1996-06-19                      Rome
# 76   7. Attacking Midfield    1999-07-02                     Massa
# 77      10. Second Striker    2000-02-18               Bentivoglio
# 78      10. Second Striker    2000-12-28                     Monza
# 79      11. Centre-Forward    2002-07-02  Castellammare di Stabbia
# 80      11. Centre-Forward    1999-05-19                      Cles
# 81      11. Centre-Forward    2000-09-10                Moncalieri
# 82      11. Centre-Forward    2008-03-10                     Milan
# 83      11. Centre-Forward    1999-01-01                      Rome
# 84      11. Centre-Forward    1999-04-29              San Fernando
# 85      11. Centre-Forward    2000-02-28                  Vercelli
# 86      11. Centre-Forward    1998-01-03                      Como
# 87      11. Centre-Forward    2001-03-17                     Genoa
    return 'Between 30 and 35'
  else:
    return 'Older than 35'

# Applying the function above on a column of the dataset and generating a new column as result:
players['Age group'] = players.apply(age_groups, axis=1)
players.tail()
# Out:
#                    Name       Club Club country     Sector  \
# 111       Giuseppe Caso  Frosinone        Italy  4. Attack
# 112  Samuele Mulattieri   Sassuolo        Italy  4. Attack
# 113      Andrea Petagna      Monza        Italy  4. Attack
# 114       Ciro Immobile      Lazio        Italy  4. Attack
# 115       Kelvin Yeboah      Genoa        Italy  4. Attack
#
#                Position Date of birth     City of birth  \
# 111      9. Left Winger    1998-12-09  Torre Annunziata
# 112  11. Centre-Forward    2000-10-07         La Spezia
# 113  11. Centre-Forward    1995-06-30           Trieste
# 114  11. Centre-Forward    1990-02-20  Torre Annunziata
# 115  11. Centre-Forward    2000-05-06             Accra
#
#            Region of birth Country of birth  \
# 111               Campania            Italy
# 112                Liguria            Italy
# 113  Friuli-Venezia Giulia            Italy
# 114               Campania            Italy
# 115                 Abroad            Ghana
#
#                                             Youth club  \
# 111                                         Fiorentina
# 112                                Spezia, Inter Milan
# 113                  Itala San Marco, Donatello, Milan
# 114  Torre Annunziata '88, Maria Rosa Salerno, Sale...
# 115                           West Ham United, Gozzano
#
#                                     Transfermarkt link Youth NT experience?  \
# 111  https://www.transfermarkt.com/giuseppe-caso/pr...                   No
# 112  https://www.transfermarkt.com/samuele-mulattie...                  Yes
# 113  https://www.transfermarkt.com/andrea-petagna/p...                  Yes
# 114  https://www.transfermarkt.com/ciro-immobile/pr...                  Yes
# 115  https://www.transfermarkt.com/kelvin-yeboah/pr...                  Yes
#
#      Age          Age group
# 111   25  Between 24 and 30
# 112   23  Between 20 and 23
# 113   29  Between 24 and 30
# 114   34  Between 30 and 35
# 115   24  Between 24 and 30

# %%
# Displaying players by their age groups:
players['Age group'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Age groups', fontweight = 'bold')
plt.show()

# %%
# Splitting the youth clubs by comma and removing leading spaces:
players['Youth club'] = players['Youth club'].str.split(',').apply(lambda x : [i.strip() for i in x])

# Exploding the list into separate rows:
players = players.explode('Youth club')

# Counting Matrix using crosstab method:
club_counts = pd.crosstab(index = players.index, columns = players['Youth club'], margins = False).to_dict('index')
club_counts = pd.DataFrame(club_counts)

# Counting the number of 0s and 1s in each row:
counts = (club_counts.apply(lambda row : [sum(row == 0), sum(row == 1)], axis = 1))

# %%
# Defining and displaying the final count with 2 columns ('False' and 'True'):
counts = pd.DataFrame(counts.tolist(), index = counts.index, columns = ['False', 'True'])
print(counts)
# Out:
#                           False  True
# 1. CfR Pforzheim            115     1
# ASD Club Napoli             115     1
# ASD San Giacomo             115     1
# Accademia Inter             115     1
# Afforese                    115     1
# ...                         ...   ...
# Vigontina                   115     1
# Vigor Perconti              115     1
# Virtus Foligno              115     1
# West Ham United             115     1
# Western Sydney Wanderers    115     1
#
# [132 rows x 2 columns]

# %%
# Displaying the youth clubs that most formed players to play in the NT:
counts['True'].sort_values(ascending = False).plot(kind = 'barh', color = 'green', figsize = (8, 30))
plt.ylabel(None)
plt.title('Youth clubs that most formed players', fontweight = 'bold')
plt.show()
