# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoalAnalysis/blob/main/ItalianPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil) (1.16.0)

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from datetime import datetime, date
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-2-db3af1e1316c>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing and displaying the last 10 players:
df = pd.ExcelFile('it-players.xlsx')
players = pd.read_excel(df, 'it-players')
players.tail(10)
# Out:
#                     Name          Club Club country     Sector  \
# 91    Matteo Cancellieri         Lazio        Italy  4. Attack
# 92       Matteo Politano        Napoli        Italy  4. Attack
# 93     Riccardo Orsolini       Bologna        Italy  4. Attack
# 94       Wilfried Gnonto  Leeds United      England  4. Attack
# 95       Mattia Zaccagni         Lazio        Italy  4. Attack
# 96         Luca Koleosho       Burnley      England  4. Attack
# 97       Federico Chiesa      Juventus        Italy  4. Attack
# 98       Riccardo Sottil    Fiorentina        Italy  4. Attack
# 99   Stephan El Shaarawy          Roma        Italy  4. Attack
# 100       Vincenzo Grifo      Freiburg      Germany  4. Attack
#
#             Position Date of birth  City of birth Region of birth  \
# 91   8. Right Winger    2002-02-12           Rome           Lazio
# 92   8. Right Winger    1993-08-03           Rome           Lazio
# 93   8. Right Winger    1997-01-24  Ascoli Piceno          Marche
# 94   8. Right Winger    2003-11-05       Verbania        Piedmont
# 95    9. Left Winger    1995-06-16         Cesena  Emilia-Romagna
# 96    9. Left Winger    2004-09-15        Norwalk          Abroad
# 97    9. Left Winger    1997-02-25          Genoa         Liguria
# 98    9. Left Winger    1999-06-03          Turin        Piedmont
# 99    9. Left Winger    1992-10-27         Savona         Liguria
# 100   9. Left Winger    1993-04-07      Pforzheim          Abroad
#
#              Country of birth  \
# 91                      Italy
# 92                      Italy
# 93                      Italy
# 94                      Italy
# 95                      Italy
# 96   United States of America
# 97                      Italy
# 98                      Italy
# 99                      Italy
# 100                   Germany
#
#                                             Youth club  \
# 91                                 Roma, Hellas Verona
# 92                                                Roma
# 93                                              Ascoli
# 94                           Baveno, Suno, Inter Milan
# 95                                       Bellaria Igea
# 96   Trumbull United, Manhattan Kickers, Reus, Espa...
# 97                            Settignanese, Fiorentina
# 98                           Genoa, Torino, Fiorentina
# 99                                       Legino, Genoa
# 100  1. CfR Pforzheim, Germania Brötzingen, Karlsru...
#
#                                     Transfermarkt link Youth NT experience?
# 91   https://www.transfermarkt.com/matteo-cancellie...                  Yes
# 92   https://www.transfermarkt.com/matteo-politano/...                  Yes
# 93   https://www.transfermarkt.com/riccardo-orsolin...                  Yes
# 94   https://www.transfermarkt.com/wilfried-gnonto/...                  Yes
# 95   https://www.transfermarkt.com/mattia-zaccagni/...                   No
# 96   https://www.transfermarkt.com/luca-koleosho/pr...                  Yes
# 97   https://www.transfermarkt.com/federico-chiesa/...                  Yes
# 98   https://www.transfermarkt.com/riccardo-sottil/...                  Yes
# 99   https://www.transfermarkt.com/stephan-el-shaar...                  Yes
# 100  https://www.transfermarkt.com/vincenzo-grifo/p...                  Yes

# %%
# Displaying the number of rows and columns in the dataset:
players.shape
# Out:
# (101, 12)

# %%
# Displaying the datatypes of each column:
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  101 non-null    object
#  1   Club                  100 non-null    object
#  2   Club country          100 non-null    object
#  3   Sector                101 non-null    object
#  4   Position              101 non-null    object
#  5   Date of birth         101 non-null    datetime64[ns]
#  6   City of birth         101 non-null    object
#  7   Region of birth       101 non-null    object
#  8   Country of birth      101 non-null    object
#  9   Youth club            101 non-null    object
#  10  Transfermarkt link    101 non-null    object
#  11  Youth NT experience?  101 non-null    object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 9.6+ KB

# %%
# Displaying players by club:
players['Club'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 12))
plt.ylabel(None)
plt.title('Players by club', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country where they play at:
players['Club country'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 4))
plt.ylabel(None)
plt.title('Players by country where they play at', fontweight = 'bold')
plt.show()

# %%
# Displaying players by sector:
players['Sector'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by sector', fontweight = 'bold')
plt.show()

# %%
# Displaying players by position:
players['Position'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by position', fontweight = 'bold')
plt.show()

# %%
# Displaying players by region of birth:
players['Region of birth'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 8))
plt.ylabel(None)
plt.title('Players by region of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country of birth:
players['Country of birth'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by country of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by the experience they had in the youth NT:
players['Youth NT experience?'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Youth NT experience?', fontweight = 'bold')
plt.show()

# %%
# Generating the column 'Age':
now = date.today()
players['Age'] = players.apply(lambda x: relativedelta(now, x['Date of birth']).years if x['Date of birth'] is not pd.NaT else pd.NaT, axis=1)
players.tail(50)
# Out:
#                     Name              Club Club country       Sector  \
# 51          Matteo Prati          Cagliari        Italy  3. Midfield
# 52    Rolando Mandragora        Fiorentina        Italy  3. Midfield
# 53         Sandro Tonali  Newcastle United      England  3. Midfield
# 54         Samuele Ricci            Torino        Italy  3. Midfield
# 55       Bryan Cristante              Roma        Italy  3. Midfield
# 56        Nicolò Rovella             Lazio        Italy  3. Midfield
# 57      Giovanni Fabbian           Bologna        Italy  3. Midfield
# 58   Gaetano Castrovilli               NaN          NaN  3. Midfield
# 59         Fabio Miretti          Juventus        Italy  3. Midfield
# 60        Cesare Casadei           Chelsea      England  3. Midfield
# 61       Davide Frattesi       Inter Milan        Italy  3. Midfield
# 62        Jacopo Fazzini            Empoli        Italy  3. Midfield
# 63        Marco Verratti          Al-Arabi        Qatar  3. Midfield
# 64        Matteo Pessina             Monza        Italy  3. Midfield
# 65    Michael Folorunsho            Napoli        Italy  3. Midfield
# 66        Nicolò Barella       Inter Milan        Italy  3. Midfield
# 67        Nicolò Fagioli          Juventus        Italy  3. Midfield
# 68        Tommaso Pobega             Milan        Italy  3. Midfield
# 69       Giulio Maggiore       Salernitana        Italy  3. Midfield
# 70        Simone Pafundi          Lausanne  Switzerland  3. Midfield
# 71      Tommaso Baldanzi              Roma        Italy  3. Midfield
# 72        Andrea Colpani             Monza        Italy  3. Midfield
# 73      Cristian Volpato          Sassuolo        Italy  3. Midfield
# 74        Daniel Maldini             Milan        Italy  3. Midfield
# 75    Lorenzo Pellegrini              Roma        Italy  3. Midfield
# 76        Nicolò Zaniolo          Atalanta        Italy  3. Midfield
# 77     Giacomo Raspadori            Napoli        Italy    4. Attack
# 78      Nicolò Cambiaghi           Bologna        Italy    4. Attack
# 79        Andrea Belotti              Como        Italy    4. Attack
# 80   Sebastiano Esposito       Inter Milan        Italy    4. Attack
# 81      Andrea Pinamonti          Sassuolo        Italy    4. Attack
# 82         Lorenzo Lucca           Udinese        Italy    4. Attack
# 83     Francesco Camarda             Milan        Italy    4. Attack
# 84     Gianluca Scamacca          Atalanta        Italy    4. Attack
# 85         Mateo Retegui             Genoa        Italy    4. Attack
# 86            Moise Kean        Fiorentina        Italy    4. Attack
# 87       Patrick Cutrone              Como        Italy    4. Attack
# 88       Pietro Pellegri            Torino        Italy    4. Attack
# 89       Lorenzo Colombo             Milan        Italy    4. Attack
# 90      Domenico Berardi          Sassuolo        Italy    4. Attack
# 91    Matteo Cancellieri             Lazio        Italy    4. Attack
# 92       Matteo Politano            Napoli        Italy    4. Attack
# 93     Riccardo Orsolini           Bologna        Italy    4. Attack
# 94       Wilfried Gnonto      Leeds United      England    4. Attack
# 95       Mattia Zaccagni             Lazio        Italy    4. Attack
# 96         Luca Koleosho           Burnley      England    4. Attack
# 97       Federico Chiesa          Juventus        Italy    4. Attack
# 98       Riccardo Sottil        Fiorentina        Italy    4. Attack
# 99   Stephan El Shaarawy              Roma        Italy    4. Attack
# 100       Vincenzo Grifo          Freiburg      Germany    4. Attack
#
#                   Position Date of birth             City of birth  \
# 51   5. Defensive Midfield    2003-12-28                   Ravenna
# 52   5. Defensive Midfield    1997-06-29                    Naples
# 53   5. Defensive Midfield    2000-05-08                      Lodi
# 54   5. Defensive Midfield    2001-08-21                 Pontedera
# 55   5. Defensive Midfield    1995-03-03   San Vito al Tagliamento
# 56   5. Defensive Midfield    2001-12-04                   Segrate
# 57     6. Central Midfield    2003-01-14             Camposampiero
# 58     6. Central Midfield    1997-02-17          Canosa di Puglia
# 59     6. Central Midfield    2003-08-03                  Pinerolo
# 60     6. Central Midfield    2003-01-10                   Ravenna
# 61     6. Central Midfield    1999-09-22                      Rome
# 62     6. Central Midfield    2003-03-16                     Massa
# 63     6. Central Midfield    1992-11-05                   Pescara
# 64     6. Central Midfield    1997-04-21                     Monza
# 65     6. Central Midfield    1998-02-07                      Rome
# 66     6. Central Midfield    1997-02-07                  Caglairi
# 67     6. Central Midfield    2001-02-12                  Piacenza
# 68     6. Central Midfield    1999-07-15                   Trieste
# 69     6. Central Midfield    1998-03-12                     Genoa
# 70   7. Attacking Midfield    2006-03-14                Monfalcone
# 71   7. Attacking Midfield    2003-03-23                Poggibonsi
# 72   7. Attacking Midfield    1999-05-11                   Brescia
  elif age >= 30 and age <= 35:
    return 'Between 30 and 35'
  else:
    return 'Older than 35'

# Applying the function above on a column of the dataset and generating a new column as result:
players['Age group'] = players.apply(age_groups, axis=1)
players.tail()
# Out:
#                     Name        Club Club country     Sector        Position  \
# 96         Luca Koleosho     Burnley      England  4. Attack  9. Left Winger
# 97       Federico Chiesa    Juventus        Italy  4. Attack  9. Left Winger
# 98       Riccardo Sottil  Fiorentina        Italy  4. Attack  9. Left Winger
# 99   Stephan El Shaarawy        Roma        Italy  4. Attack  9. Left Winger
# 100       Vincenzo Grifo    Freiburg      Germany  4. Attack  9. Left Winger
#
#     Date of birth City of birth Region of birth          Country of birth  \
# 96     2004-09-15       Norwalk          Abroad  United States of America
# 97     1997-02-25         Genoa         Liguria                     Italy
# 98     1999-06-03         Turin        Piedmont                     Italy
# 99     1992-10-27        Savona         Liguria                     Italy
# 100    1993-04-07     Pforzheim          Abroad                   Germany
#
#                                             Youth club  \
# 96   Trumbull United, Manhattan Kickers, Reus, Espa...
# 97                            Settignanese, Fiorentina
# 98                           Genoa, Torino, Fiorentina
# 99                                       Legino, Genoa
# 100  1. CfR Pforzheim, Germania Brötzingen, Karlsru...
#
#                                     Transfermarkt link Youth NT experience?  \
# 96   https://www.transfermarkt.com/luca-koleosho/pr...                  Yes
# 97   https://www.transfermarkt.com/federico-chiesa/...                  Yes
# 98   https://www.transfermarkt.com/riccardo-sottil/...                  Yes
# 99   https://www.transfermarkt.com/stephan-el-shaar...                  Yes
# 100  https://www.transfermarkt.com/vincenzo-grifo/p...                  Yes
#
#      Age          Age group
# 96    19           Under 20
# 97    27  Between 24 and 30
# 98    25  Between 24 and 30
# 99    31  Between 30 and 35
# 100   31  Between 30 and 35

# %%
# Displaying players by their age groups:
players['Age group'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Age groups', fontweight = 'bold')
plt.show()

# %%
# Splitting the youth clubs by comma and removing leading spaces:
players['Youth club'] = players['Youth club'].str.split(',').apply(lambda x : [i.strip() for i in x])

# Exploding the list into separate rows:
players = players.explode('Youth club')

# Counting Matrix using crosstab method:
club_counts = pd.crosstab(index = players.index, columns = players['Youth club'], margins = False).to_dict('index')
club_counts = pd.DataFrame(club_counts)

# Counting the number of 0s and 1s in each row:
counts = (club_counts.apply(lambda row : [sum(row == 0), sum(row == 1)], axis = 1))

# %%
# Defining and displaying the final count with 2 columns ('False' and 'True'):
counts = pd.DataFrame(counts.tolist(), index = counts.index, columns = ['False', 'True'])
print(counts)
# Out:
#                           False  True
# 1. CfR Pforzheim            100     1
# ASD Club Napoli             100     1
# Accademia Inter             100     1
# Afforese                    100     1
# AlbinoLeffe                 100     1
# ...                         ...   ...
# Viareggio                   100     1
# Vicenza                      98     3
# Vigor Perconti              100     1
# Virtus Foligno              100     1
# Western Sydney Wanderers    100     1
#
# [119 rows x 2 columns]

# %%
# Displaying the youth clubs that most formed players to play in the NT:
counts['True'].sort_values(ascending = False).plot(kind = 'barh', color = 'green', figsize = (8, 30))
plt.ylabel(None)
plt.title('Youth clubs that most formed players', fontweight = 'bold')
plt.show()
