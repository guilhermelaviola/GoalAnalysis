# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoalAnalysis/blob/main/ItalianPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil) (1.16.0)

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from datetime import datetime, date
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-93-db3af1e1316c>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing and displaying the last 10 players:
df = pd.ExcelFile('it-players.xlsx')
players = pd.read_excel(df, 'it-players')
players.tail(10)
# Out:
#                     Name          Club Club country     Sector  \
# 108      Wilfried Gnonto  Leeds United      England  4. Attack
# 109        Luca D'Andrea      Sassuolo        Italy  4. Attack
# 110  Stephan El Shaarawy          Roma        Italy  4. Attack
# 111       Vincenzo Grifo      Freiburg      Germany  4. Attack
# 112      Mattia Zaccagni         Lazio        Italy  4. Attack
# 113      Federico Chiesa      Juventus        Italy  4. Attack
# 114        Giuseppe Caso     Frosinone        Italy  4. Attack
# 115       Alessio Zerbin        Napoli        Italy  4. Attack
# 116      Riccardo Sottil    Fiorentina        Italy  4. Attack
# 117        Luca Koleosho       Burnley      England  4. Attack
#
#             Position Date of birth     City of birth Region of birth  \
# 108  8. Right Winger    2003-11-05          Verbania        Piedmont
# 109  8. Right Winger    2004-09-06            Naples        Campania
# 110   9. Left Winger    1992-10-27            Savona         Liguria
# 111   9. Left Winger    1993-04-07         Pforzheim          Abroad
# 112   9. Left Winger    1995-06-16            Cesena  Emilia-Romagna
# 113   9. Left Winger    1997-02-25             Genoa         Liguria
# 114   9. Left Winger    1998-12-09  Torre Annunziata        Campania
# 115   9. Left Winger    1999-03-03            Novara        Piedmont
# 116   9. Left Winger    1999-06-03             Turin        Piedmont
# 117   9. Left Winger    2004-09-15           Norwalk          Abroad
#
#              Country of birth  \
# 108                     Italy
# 109                     Italy
# 110                     Italy
# 111                   Germany
# 112                     Italy
# 113                     Italy
# 114                     Italy
# 115                     Italy
# 116                     Italy
# 117  United States of America
#
#                                             Youth club  \
# 108                          Baveno, Suno, Inter Milan
# 109  Ponticelli, Mariano Keller, Scuola Calcio Azzu...
# 110                                      Legino, Genoa
# 111  1. CfR Pforzheim, Germania Brötzingen, Karlsru...
# 112                                      Bellaria Igea
# 113                           Settignanese, Fiorentina
# 114                                         Fiorentina
# 115         Inter Milan, Novara, Suno, Gozzano, Napoli
# 116                          Genoa, Torino, Fiorentina
# 117  Trumbull United, Manhattan Kickers, Reus, Espa...
#
#                                     Transfermarkt link Youth NT experience?  \
# 108  https://www.transfermarkt.com/wilfried-gnonto/...                  Yes
# 109  https://www.transfermarkt.com/luca-dandrea/pro...                  Yes
# 110  https://www.transfermarkt.com/stephan-el-shaar...                  Yes
# 111  https://www.transfermarkt.com/vincenzo-grifo/p...                  Yes
# 112  https://www.transfermarkt.com/mattia-zaccagni/...                   No
# 113  https://www.transfermarkt.com/federico-chiesa/...                  Yes
# 114  https://www.transfermarkt.com/giuseppe-caso/pr...                   No
# 115  https://www.transfermarkt.com/alessio-zerbin/p...                  Yes
# 116  https://www.transfermarkt.com/riccardo-sottil/...                  Yes
# 117  https://www.transfermarkt.com/luca-koleosho/pr...                  Yes
#
#       Transfermarkt name  Transfermarkt ID
# 108      wilfried-gnonto            627626
# 109         luca-dandrea            725242
# 110  stephan-el-shaarawy             94529
# 111       vincenzo-grifo            185077
# 112      mattia-zaccagni            283735
# 113      federico-chiesa            341092
# 114        giuseppe-caso            398030
# 115       alessio-zerbin            433584
# 116      riccardo-sottil            386455
# 117        luca-koleosho            745461

# %%
# Displaying the number of rows and columns in the dataset:
players.shape
# Out:
# (118, 14)

# %%
# Displaying the datatypes of each column:
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  118 non-null    object
#  1   Club                  118 non-null    object
#  2   Club country          118 non-null    object
#  3   Sector                118 non-null    object
#  4   Position              118 non-null    object
#  5   Date of birth         118 non-null    datetime64[ns]
#  6   City of birth         118 non-null    object
#  7   Region of birth       118 non-null    object
#  8   Country of birth      118 non-null    object
#  9   Youth club            118 non-null    object
#  10  Transfermarkt link    118 non-null    object
#  11  Youth NT experience?  118 non-null    object
#  12  Transfermarkt name    118 non-null    object
#  13  Transfermarkt ID      118 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 13.0+ KB

# %%
# Displaying players by club:
players['Club'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 12))
plt.ylabel(None)
plt.title('Players by club', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country where they play at:
players['Club country'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 4))
plt.ylabel(None)
plt.title('Players by country where they play at', fontweight = 'bold')
plt.show()

# %%
# Displaying players by sector:
players['Sector'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by sector', fontweight = 'bold')
plt.show()

# %%
# Displaying players by position:
players['Position'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by position', fontweight = 'bold')
plt.show()

# %%
# Displaying players by region of birth:
players['Region of birth'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 8))
plt.ylabel(None)
plt.title('Players by region of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country of birth:
players['Country of birth'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by country of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by the experience they had in the youth NT:
players['Youth NT experience?'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Youth NT experience?', fontweight = 'bold')
plt.show()

# %%
# Generating the column 'Age':
now = date.today()
players['Age'] = players.apply(lambda x: relativedelta(now, x['Date of birth']).years if x['Date of birth'] is not pd.NaT else pd.NaT, axis=1)
players.tail(50)
# Out:
#                     Name          Club Club country       Sector  \
# 68        Tommaso Pobega         Milan        Italy  3. Midfield
# 69       Davide Frattesi   Inter Milan        Italy  3. Midfield
# 70     Marco Brascianini     Frosinone        Italy  3. Midfield
# 71        Nicolò Fagioli      Juventus        Italy  3. Midfield
# 72          Edoardo Bove          Roma        Italy  3. Midfield
# 73        Cesare Casadei       Chelsea      England  3. Midfield
# 74      Giovanni Fabbian       Bologna        Italy  3. Midfield
# 75        Jacopo Fazzini        Empoli        Italy  3. Midfield
# 76         Fabio Miretti      Juventus        Italy  3. Midfield
# 77            Cher Ndour           PSG       France  3. Midfield
# 78    Lorenzo Pellegrini          Roma        Italy  3. Midfield
# 79        Andrea Colpani         Monza        Italy  3. Midfield
# 80        Nicolò Zaniolo      Atalanta        Italy  3. Midfield
# 81      Gianluca Gaetano        Napoli        Italy  3. Midfield
# 82        Daniel Maldini         Milan        Italy  3. Midfield
# 83        Daniel Maldini         Milan        Italy  3. Midfield
# 84     Gaetano Oristanio       Venezia        Italy  3. Midfield
# 85      Tommaso Baldanzi          Roma        Italy  3. Midfield
# 86      Cristian Volpato      Sassuolo        Italy  3. Midfield
# 87        Simone Pafundi      Lausanne  Switzerland  3. Midfield
# 88     Giacomo Raspadori        Napoli        Italy    4. Attack
# 89      Nicolò Cambiaghi       Bologna        Italy    4. Attack
# 90         Ciro Immobile         Lazio        Italy    4. Attack
# 91        Andrea Petagna         Monza        Italy    4. Attack
# 92       Patrick Cutrone          Como        Italy    4. Attack
# 93     Gianluca Scamacca      Atalanta        Italy    4. Attack
# 94         Mateo Retegui         Genoa        Italy    4. Attack
# 95      Andrea Pinamonti      Sassuolo        Italy    4. Attack
# 96            Moise Kean    Fiorentina        Italy    4. Attack
# 97         Kelvin Yeboah         Genoa        Italy    4. Attack
# 98         Lorenzo Lucca       Udinese        Italy    4. Attack
# 99    Samuele Mulattieri      Sassuolo        Italy    4. Attack
# 100      Pietro Pellegri        Torino        Italy    4. Attack
# 101      Lorenzo Colombo         Milan        Italy    4. Attack
# 102  Sebastiano Esposito   Inter Milan        Italy    4. Attack
# 103    Francesco Camarda         Milan        Italy    4. Attack
# 104      Matteo Politano        Napoli        Italy    4. Attack
# 105     Domenico Berardi      Sassuolo        Italy    4. Attack
# 106    Riccardo Orsolini       Bologna        Italy    4. Attack
# 107   Matteo Cancellieri         Lazio        Italy    4. Attack
# 108      Wilfried Gnonto  Leeds United      England    4. Attack
# 109        Luca D'Andrea      Sassuolo        Italy    4. Attack
# 110  Stephan El Shaarawy          Roma        Italy    4. Attack
# 111       Vincenzo Grifo      Freiburg      Germany    4. Attack
# 112      Mattia Zaccagni         Lazio        Italy    4. Attack
# 113      Federico Chiesa      Juventus        Italy    4. Attack
# 114        Giuseppe Caso     Frosinone        Italy    4. Attack
# 115       Alessio Zerbin        Napoli        Italy    4. Attack
# 116      Riccardo Sottil    Fiorentina        Italy    4. Attack
# 117        Luca Koleosho       Burnley      England    4. Attack
#
#                   Position Date of birth             City of birth  \
# 68     6. Central Midfield    1999-07-15                   Trieste
# 69     6. Central Midfield    1999-09-22                      Rome
# 70     6. Central Midfield    2000-02-20                 Calcinate
# 71     6. Central Midfield    2001-02-12                  Piacenza
# 72     6. Central Midfield    2002-05-16                      Rome
# 110  https://www.transfermarkt.com/stephan-el-shaar...                  Yes
# 111  https://www.transfermarkt.com/vincenzo-grifo/p...                  Yes
# 112  https://www.transfermarkt.com/mattia-zaccagni/...                   No
# 113  https://www.transfermarkt.com/federico-chiesa/...                  Yes
# 114  https://www.transfermarkt.com/giuseppe-caso/pr...                   No
# 115  https://www.transfermarkt.com/alessio-zerbin/p...                  Yes
# 116  https://www.transfermarkt.com/riccardo-sottil/...                  Yes
# 117  https://www.transfermarkt.com/luca-koleosho/pr...                  Yes
#
#       Transfermarkt name  Transfermarkt ID  Age
# 68        tommaso-pobega            392538   25
# 69       davide-frattesi            394300   24
# 70     marco-brescianini            459128   24
# 71        nicolo-fagioli            432090   23
# 72          edoardo-bove            562049   22
# 73        cesare-casadei            622380   21
# 74      giovanni-fabbian            633668   21
# 75        jacopo-fazzini            691482   21
# 76         fabio-miretti            571607   20
# 77            cher-ndour            651005   19
# 78    lorenzo-pellegrini            286297   28
# 79        andrea-colpani            392959   25
# 80        nicolo-zaniolo            392085   25
# 81      gianluca-gaetano            358008   24
# 82        daniel-maldini            539134   22
# 83        daniel-maldini            539134   22
# 84     gaetano-oristanio            613393   21
# 85      tommaso-baldanzi            641537   21
# 86      cristian-volpato            746891   20
# 87        simone-pafundi            876400   18
# 88     giacomo-raspadori            405885   24
# 89      nicolo-cambiaghi            459151   23
# 90         ciro-immobile            105521   34
# 91        andrea-petagna            199258   29
# 92       patrick-cutrone            265078   26
# 93     gianluca-scamacca            315867   25
# 94         mateo-retegui            554903   25
# 95      andrea-pinamonti            315865   25
# 96            moise-kean            364135   24
# 97         kelvin-yeboah            589737   24
# 98         lorenzo-lucca            572265   23
# 99    samuele-mulattieri            457422   23
# 100      pietro-pellegri            364133   23
# 101      lorenzo-colombo            487843   22
# 102  sebastiano-esposito            538918   22
# 103    francesco-camarda           1058368   16
# 104      matteo-politano            165895   30
# 105     domenico-berardi            177843   29
# 106    riccardo-orsolini            368482   27
# 107   matteo-cancellieri            550106   22
# 108      wilfried-gnonto            627626   20
# 109         luca-dandrea            725242   19
# 110  stephan-el-shaarawy             94529   31
# 111       vincenzo-grifo            185077   31
# 112      mattia-zaccagni            283735   29
# 113      federico-chiesa            341092   27
# 114        giuseppe-caso            398030   25
# 115       alessio-zerbin            433584   25
# 116      riccardo-sottil            386455   25
# 117        luca-koleosho            745461   19

# %%
# Grouping players by their age group:
def age_groups(row):
  age = row['Age']

  if age < 20:
    return 'Under 20'
  elif age >= 20 and age < 24:
    return 'Between 20 and 23'
  elif age >= 24 and age < 30:
    return 'Between 24 and 30'
  elif age >= 30 and age <= 35:
    return 'Between 30 and 35'
  else:
    return 'Older than 35'

# Applying the function above on a column of the dataset and generating a new column as result:
players['Age group'] = players.apply(age_groups, axis=1)
players.tail()
# Out:
#                 Name        Club Club country     Sector        Position  \
# 113  Federico Chiesa    Juventus        Italy  4. Attack  9. Left Winger
# 114    Giuseppe Caso   Frosinone        Italy  4. Attack  9. Left Winger
# 115   Alessio Zerbin      Napoli        Italy  4. Attack  9. Left Winger
# 116  Riccardo Sottil  Fiorentina        Italy  4. Attack  9. Left Winger
# 117    Luca Koleosho     Burnley      England  4. Attack  9. Left Winger
#
#     Date of birth     City of birth Region of birth          Country of birth  \
# 113    1997-02-25             Genoa         Liguria                     Italy
# 114    1998-12-09  Torre Annunziata        Campania                     Italy
# 115    1999-03-03            Novara        Piedmont                     Italy
# 116    1999-06-03             Turin        Piedmont                     Italy
# 117    2004-09-15           Norwalk          Abroad  United States of America
#
#                                             Youth club  \
# 113                           Settignanese, Fiorentina
# 114                                         Fiorentina
# 115         Inter Milan, Novara, Suno, Gozzano, Napoli
# 116                          Genoa, Torino, Fiorentina
# 117  Trumbull United, Manhattan Kickers, Reus, Espa...
#
#                                     Transfermarkt link Youth NT experience?  \
# 113  https://www.transfermarkt.com/federico-chiesa/...                  Yes
# 114  https://www.transfermarkt.com/giuseppe-caso/pr...                   No
# 115  https://www.transfermarkt.com/alessio-zerbin/p...                  Yes
# 116  https://www.transfermarkt.com/riccardo-sottil/...                  Yes
# 117  https://www.transfermarkt.com/luca-koleosho/pr...                  Yes
#
#     Transfermarkt name  Transfermarkt ID  Age          Age group
# 113    federico-chiesa            341092   27  Between 24 and 30
# 114      giuseppe-caso            398030   25  Between 24 and 30
# 115     alessio-zerbin            433584   25  Between 24 and 30
# 116    riccardo-sottil            386455   25  Between 24 and 30
# 117      luca-koleosho            745461   19           Under 20

# %%
# Displaying players by their age groups:
players['Age group'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Age groups', fontweight = 'bold')
plt.show()

# %%
# Splitting the youth clubs by comma and removing leading spaces:
players['Youth club'] = players['Youth club'].str.split(',').apply(lambda x : [i.strip() for i in x])

# Exploding the list into separate rows:
players = players.explode('Youth club')

# Counting Matrix using crosstab method:
club_counts = pd.crosstab(index = players.index, columns = players['Youth club'], margins = False).to_dict('index')
club_counts = pd.DataFrame(club_counts)

# Counting the number of 0s and 1s in each row:
counts = (club_counts.apply(lambda row : [sum(row == 0), sum(row == 1)], axis = 1))

# %%
# Defining and displaying the final count with 2 columns ('False' and 'True'):
counts = pd.DataFrame(counts.tolist(), index = counts.index, columns = ['False', 'True'])
print(counts)
# Out:
#                           False  True
# 1. CfR Pforzheim            117     1
# ASD Club Napoli             117     1
# ASD San Giacomo             117     1
# Accademia Inter             117     1
# Afforese                    117     1
# ...                         ...   ...
# Virtus Feralpi Lonato       117     1
# Virtus Foligno              117     1
# Werder Bremen               117     1
# West Ham United             117     1
# Western Sydney Wanderers    117     1
#
# [135 rows x 2 columns]

# %%
# Displaying the youth clubs that most formed players to play in the NT:
counts['True'].sort_values(ascending = False).plot(kind = 'barh', color = 'green', figsize = (8, 30))
plt.ylabel(None)
plt.title('Youth clubs that most formed players', fontweight = 'bold')
plt.show()
