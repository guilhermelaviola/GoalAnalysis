# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoalAnalysis/blob/main/ItalianPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil) (1.16.0)

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from datetime import datetime, date
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-2-db3af1e1316c>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing and displaying the last 10 players:
df = pd.ExcelFile('it-players.xlsx')
players = pd.read_excel(df, 'it-players')
players.tail(10)
# Out:
#                     Name        Club Club country      Sector  \
# 108        Luca D'Andrea    Sassuolo        Italy   4. Attack
# 109  Stephan El Shaarawy        Roma        Italy   4. Attack
# 110       Vincenzo Grifo    Freiburg      Germany   4. Attack
# 111      Mattia Zaccagni       Lazio        Italy   4. Attack
# 112      Federico Chiesa    Juventus        Italy   4. Attack
# 113        Giuseppe Caso   Frosinone        Italy   4. Attack
# 114       Alessio Zerbin      Napoli        Italy   4. Attack
# 115      Riccardo Sottil  Fiorentina        Italy   4. Attack
# 116        Luca Koleosho     Burnley      England   4. Attack
# 117      Luca Pellegrini       Lazio        Italy  2. Defense
#
#             Position Date of birth     City of birth Region of birth  \
# 108  8. Right Winger    2004-09-06            Naples        Campania
# 109   9. Left Winger    1992-10-27            Savona         Liguria
# 110   9. Left Winger    1993-04-07         Pforzheim          Abroad
# 111   9. Left Winger    1995-06-16            Cesena  Emilia-Romagna
# 112   9. Left Winger    1997-02-25             Genoa         Liguria
# 113   9. Left Winger    1998-12-09  Torre Annunziata        Campania
# 114   9. Left Winger    1999-03-03            Novara        Piedmont
# 115   9. Left Winger    1999-06-03             Turin        Piedmont
# 116   9. Left Winger    2004-09-15           Norwalk          Abroad
# 117     4. Left-Back    1999-03-07              Rome           Lazio
#
#              Country of birth  \
# 108                     Italy
# 109                     Italy
# 110                   Germany
# 111                     Italy
# 112                     Italy
# 113                     Italy
# 114                     Italy
# 115                     Italy
# 116  United States of America
# 117                     Italy
#
#                                             Youth club Youth NT experience?
# 108  Ponticelli, Mariano Keller, Scuola Calcio Azzu...                  Yes
# 109                                      Legino, Genoa                  Yes
# 110  1. CfR Pforzheim, Germania Brötzingen, Karlsru...                  Yes
# 111                                      Bellaria Igea                   No
# 112                           Settignanese, Fiorentina                  Yes
# 113                                         Fiorentina                   No
# 114         Inter Milan, Novara, Suno, Gozzano, Napoli                  Yes
# 115                          Genoa, Torino, Fiorentina                  Yes
# 116  Trumbull United, Manhattan Kickers, Reus, Espa...                  Yes
# 117       Cinecittà Bettini, Nuova Tor Tre Teste, Roma                  Yes

# %%
# Displaying the number of rows and columns in the dataset:
players.shape
# Out:
# (118, 11)

# %%
# Displaying the datatypes of each column:
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  118 non-null    object
#  1   Club                  118 non-null    object
#  2   Club country          118 non-null    object
#  3   Sector                118 non-null    object
#  4   Position              118 non-null    object
#  5   Date of birth         118 non-null    datetime64[ns]
#  6   City of birth         118 non-null    object
#  7   Region of birth       118 non-null    object
#  8   Country of birth      118 non-null    object
#  9   Youth club            118 non-null    object
#  10  Youth NT experience?  118 non-null    object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 10.3+ KB

# %%
# Displaying players by club:
players['Club'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 12))
plt.ylabel(None)
plt.title('Players by club', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country where they play at:
players['Club country'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 4))
plt.ylabel(None)
plt.title('Players by country where they play at', fontweight = 'bold')
plt.show()

# %%
# Displaying players by sector:
players['Sector'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by sector', fontweight = 'bold')
plt.show()

# %%
# Displaying players by position:
players['Position'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by position', fontweight = 'bold')
plt.show()

# %%
# Displaying players by region of birth:
players['Region of birth'].value_counts().plot(kind = 'barh', color = 'green', figsize = (8, 8))
plt.ylabel(None)
plt.title('Players by region of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by country of birth:
players['Country of birth'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Players by country of birth', fontweight = 'bold')
plt.show()

# %%
# Displaying players by the experience they had in the youth NT:
players['Youth NT experience?'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Youth NT experience?', fontweight = 'bold')
plt.show()

# %%
# Generating the column 'Age':
now = date.today()
players['Age'] = players.apply(lambda x: relativedelta(now, x['Date of birth']).years if x['Date of birth'] is not pd.NaT else pd.NaT, axis=1)
players.tail(50)
# Out:
#                     Name          Club Club country       Sector  \
# 68        Tommaso Pobega         Milan        Italy  3. Midfield
# 69       Davide Frattesi   Inter Milan        Italy  3. Midfield
# 70     Marco Brascianini     Frosinone        Italy  3. Midfield
# 71        Nicolò Fagioli      Juventus        Italy  3. Midfield
# 72          Edoardo Bove          Roma        Italy  3. Midfield
# 73        Cesare Casadei       Chelsea      England  3. Midfield
# 74      Giovanni Fabbian       Bologna        Italy  3. Midfield
# 75        Jacopo Fazzini        Empoli        Italy  3. Midfield
# 76         Fabio Miretti      Juventus        Italy  3. Midfield
# 77            Cher Ndour           PSG       France  3. Midfield
# 78    Lorenzo Pellegrini          Roma        Italy  3. Midfield
# 79        Andrea Colpani    Fiorentina        Italy  3. Midfield
# 80        Nicolò Zaniolo      Atalanta        Italy  3. Midfield
# 81      Gianluca Gaetano        Napoli        Italy  3. Midfield
# 82        Daniel Maldini         Milan        Italy  3. Midfield
# 83     Gaetano Oristanio       Venezia        Italy  3. Midfield
# 84      Tommaso Baldanzi          Roma        Italy  3. Midfield
# 85      Cristian Volpato      Sassuolo        Italy  3. Midfield
# 86        Simone Pafundi      Lausanne  Switzerland  3. Midfield
# 87     Giacomo Raspadori        Napoli        Italy    4. Attack
# 88      Nicolò Cambiaghi       Bologna        Italy    4. Attack
# 89         Ciro Immobile      Besiktas       Turkey    4. Attack
# 90        Andrea Petagna         Monza        Italy    4. Attack
# 91       Patrick Cutrone          Como        Italy    4. Attack
# 92     Gianluca Scamacca      Atalanta        Italy    4. Attack
# 93         Mateo Retegui         Genoa        Italy    4. Attack
# 94      Andrea Pinamonti      Sassuolo        Italy    4. Attack
# 95            Moise Kean    Fiorentina        Italy    4. Attack
# 79                                            Atalanta                  Yes
# 80                                   Genoa, Fiorentina                  Yes
# 81                     Future Boys di Cimitile, Napoli                  Yes
# 82                                               Milan                  Yes
# 83                                         Inter Milan                  Yes
# 84                                              Empoli                  Yes
# 85   Sydney United, Sydney FC, Western Sydney Wande...                  Yes
# 86                             UFM Monfalcone, Udinese                  Yes
# 87                                 Progresso, Sassuolo                  Yes
# 88                                            Atalanta                  Yes
# 89   Torre Annunziata '88, Maria Rosa Salerno, Sale...                  Yes
# 90                   Itala San Marco, Donatello, Milan                  Yes
# 91                                   Parediense, Milan                  Yes
# 92                                    Lazio, Roma, PSV                  Yes
# 93                           River Plate, Boca Juniors                   No
# 94                          Chievo Verona, Inter Milan                  Yes
# 95                              Asti, Torino, Juventus                  Yes
# 96                            West Ham United, Gozzano                  Yes
# 97   CBS Scuola Calcio, Torino, Chieri, Vicenza, Br...                  Yes
# 98                                 Spezia, Inter Milan                  Yes
# 99                                               Genoa                  Yes
# 100                                              Milan                  Yes
# 101  Napoli Castellamare di Stabia, Brescia, Inter ...                  Yes
# 102                                    Afforese, Milan                  Yes
# 103                                               Roma                  Yes
# 104                                  Cosenza, Sassuolo                  Yes
# 105                                             Ascoli                  Yes
# 106                                Roma, Hellas Verona                  Yes
# 107                          Baveno, Suno, Inter Milan                  Yes
# 108  Ponticelli, Mariano Keller, Scuola Calcio Azzu...                  Yes
# 109                                      Legino, Genoa                  Yes
# 110  1. CfR Pforzheim, Germania Brötzingen, Karlsru...                  Yes
# 111                                      Bellaria Igea                   No
# 112                           Settignanese, Fiorentina                  Yes
# 113                                         Fiorentina                   No
# 114         Inter Milan, Novara, Suno, Gozzano, Napoli                  Yes
# 115                          Genoa, Torino, Fiorentina                  Yes
# 116  Trumbull United, Manhattan Kickers, Reus, Espa...                  Yes
# 117       Cinecittà Bettini, Nuova Tor Tre Teste, Roma                  Yes
#
#      Age
# 68    25
# 69    24
# 70    24
# 71    23
# 72    22
# 73    21
# 74    21
# 75    21
# 76    20
# 77    20
# 78    28
# 79    25
# 80    25
# 81    24
# 82    22
# 83    21
# 84    21
# 85    20
# 86    18
# 87    24
# 88    23
# 89    34
# 90    29
# 91    26
# 92    25
# 93    25
# 94    25
# 95    24
# 96    24
# 97    23
# 98    23
# 99    23
# 100   22
# 101   22
# 102   16
# 103   30
# 104   29
# 105   27
# 106   22
# 107   20
# 108   19
# 109   31
# 110   31
# 111   29
# 112   27
# 113   25
# 114   25
# 115   25
# 116   19
# 117   25

# %%
# Grouping players by their age group:
def age_groups(row):
  age = row['Age']

  if age < 20:
    return 'Under 20'
  elif age >= 20 and age < 24:
    return 'Between 20 and 23'
  elif age >= 24 and age < 30:
    return 'Between 24 and 30'
  elif age >= 30 and age <= 35:
    return 'Between 30 and 35'
  else:
    return 'Older than 35'

# Applying the function above on a column of the dataset and generating a new column as result:
players['Age group'] = players.apply(age_groups, axis=1)
players.tail()
# Out:
#                 Name        Club Club country      Sector        Position  \
# 113    Giuseppe Caso   Frosinone        Italy   4. Attack  9. Left Winger
# 114   Alessio Zerbin      Napoli        Italy   4. Attack  9. Left Winger
# 115  Riccardo Sottil  Fiorentina        Italy   4. Attack  9. Left Winger
# 116    Luca Koleosho     Burnley      England   4. Attack  9. Left Winger
# 117  Luca Pellegrini       Lazio        Italy  2. Defense    4. Left-Back
#
#     Date of birth     City of birth Region of birth          Country of birth  \
# 113    1998-12-09  Torre Annunziata        Campania                     Italy
# 114    1999-03-03            Novara        Piedmont                     Italy
# 115    1999-06-03             Turin        Piedmont                     Italy
# 116    2004-09-15           Norwalk          Abroad  United States of America
# 117    1999-03-07              Rome           Lazio                     Italy
#
#                                             Youth club Youth NT experience?  \
# 113                                         Fiorentina                   No
# 114         Inter Milan, Novara, Suno, Gozzano, Napoli                  Yes
# 115                          Genoa, Torino, Fiorentina                  Yes
# 116  Trumbull United, Manhattan Kickers, Reus, Espa...                  Yes
# 117       Cinecittà Bettini, Nuova Tor Tre Teste, Roma                  Yes
#
#      Age          Age group
# 113   25  Between 24 and 30
# 114   25  Between 24 and 30
# 115   25  Between 24 and 30
# 116   19           Under 20
# 117   25  Between 24 and 30

# %%
# Displaying players by their age groups:
players['Age group'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Age groups', fontweight = 'bold')
plt.show()

# %%
# Displaying statistical data of the numerical data present in the dataset:
players.describe()
# Out:
#                        Date of birth         Age
# count                            118  118.000000
# mean   1999-05-18 17:05:05.084745728   24.720339
# min              1988-02-10 00:00:00   16.000000
# 25%              1997-02-11 12:00:00   22.000000
# 50%              1999-08-18 12:00:00   24.500000
# 75%              2002-03-04 00:00:00   27.000000
# max              2008-03-10 00:00:00   36.000000
# std                              NaN    3.829453

# %%
# Splitting the youth clubs by comma and removing leading spaces:
players['Youth club'] = players['Youth club'].str.split(',').apply(lambda x : [i.strip() for i in x])

# Exploding the list into separate rows:
players = players.explode('Youth club')

# Counting Matrix using crosstab method:
club_counts = pd.crosstab(index = players.index, columns = players['Youth club'], margins = False).to_dict('index')
club_counts = pd.DataFrame(club_counts)

# Counting the number of 0s and 1s in each row:
counts = (club_counts.apply(lambda row : [sum(row == 0), sum(row == 1)], axis = 1))

# %%
# Defining and displaying the final count with 2 columns ('False' and 'True'):
counts = pd.DataFrame(counts.tolist(), index = counts.index, columns = ['False', 'True'])
print(counts)
# Out:
#                           False  True
# 1. CfR Pforzheim            117     1
# ASD Club Napoli             117     1
# ASD San Giacomo             117     1
# Accademia Inter             117     1
# Afforese                    117     1
# ...                         ...   ...
# Virtus Feralpi Lonato       117     1
# Virtus Foligno              117     1
# Werder Bremen               117     1
# West Ham United             117     1
# Western Sydney Wanderers    117     1
#
# [137 rows x 2 columns]

# %%
# Displaying the youth clubs that most formed players to play in the NT:
counts['True'].sort_values(ascending = False).plot(kind = 'barh', color = 'green', figsize = (8, 30))
plt.ylabel(None)
plt.title('Youth clubs that most formed players', fontweight = 'bold')
plt.show()
